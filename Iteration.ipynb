# %% [markdown]
# <a href="https://colab.research.google.com/github/aem-iv/Math600/blob/main/Iteration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code for the iteration assignment today. Make your own copy, and then change the seed and iteration value to whatever you want.
#
# And if you have never used Google Colab before, don't worry, you don't have to download something. If you have Google Drive, then you have access to Colaboratory Notebooks. Next time you go to Google Drive and click "New", check out the "More" option.

# %% [markdown]
# And to those of you with little to no experience coding, here is a little rundown of what I did. This is the short short version. There is a lot more that you can do, and I am also not tech savy, so this is almost everything I know about these coding topics. My python skills are self taught, so I learned what I needed, and skipped over everything else.
#
# Anywaays...
#
# The things I imported are called "libraries". They are like toolboxes with different groups of related tools. They each have a specific set of tasks they can help you perform. And I do the "as ..." part so that I don't have to type out the long library name every time I want to use it.
#
# - "#" makes something a "comment". It won't affect the code. Good for labeling and explaining things. Especially in longer assignments.
#
# - Math gives me access to different functions (math.sqrt(), and math.sin()) or values (math.pi, math.pi)
#
# - Numpy helps you make arrays of various sizes. So you can make single row lists or sequences, or single columns, or matrices if m=n for your array. Or it can be a collection of rows or columns. Whatever mxn object you may need.
#
#   Note: Python does have its own built in array options, so I didn't use numpy, but I preemptively put it because it is good to have.
#
# - matplotlib.pyplot is for graphing. plt.scatter(x_list, y_list) gives a scatter plot, while plt.plot(list), gives a line.
#
# "seed" and "iterations" are variables that I defined (and labeled with those names for clarity). The number after the underscore is just to distinguish them for you and for the code. If all seeds were just "seed" with no number, then the code might try to pick all of them and use them even if they had different values. Then the program might fail. Again, I'm self taught, so I know how to avoid the error, but I don't know when my prevention methods become unnecessary.
#
# ans = [], is a way to make an empty array, and you can append (fill) with values later on. I use this one to collect answers for each iteration.
#
# It's best to define whatever variables and arrays you want OUTSIDE of any "for loop" or "if statement" because if it is inside, it is ONLY defined inside, and it can't work outside. Inside and outside are in relation to the indentations. You can see layers of indentations to organize the whole process. To continue after a loop, just make a new line with no indentation. That "closes" the loop.
#
# - "for" is for iterations (Coding processes usually start at 0, kind of like x_0 in math, but notice that 0 to 10 is 11 values, but only 10 points are plotted. So you can think of the range in intervale notation like range[0, 10). If you don't like it, sorry. Just accept it. Easiest answer.) And "i" is like i in Σ notation, or n from today, or the word "index". It just keeps track of the specific iteration you are on.
#
# - "if" is for conditions (Yes, you do need two equals signs for that condition. It is checking if the value is equal rather than defining it as equal.) (Oh, and != means "not equal")
#
# A period is used to do a certain function. Not a math function, a coding one. A function like append, or sqrt, or scatter. Append is built into python, so you don't need to specify the library you get it from.
#
# Parentheses say what you do the function on.
#
# Brackets are for finding a specific item in a list. There is a lot of cool stuff you can do with them. If your array is m, n =! 1, then you will need two values in the brackets to specify a specific row and column. Just look up all the cool stuff you can do with them because I don't have that memorized.
#
# So line 12 can be read as: The array called "ans_1", add the value sqrt(seed_1) to your list.
#
# Since i is 0 (because of the if condition), then this will be the 0th value of ans_1
#
# And line 16 can be read as: The array called "ans_1", add the value sqrt(the second to last/previous value of ans_1) to your list.
#
# Since i >= 1 now, we have multiple values in ans_1, but this iterative process works by using the previous value in the list. (And you have to specify a value becuase we aren't squarerooting the entire list.) I don't want to (and can't) use ans_1[i], because I don't have it yet. I'm making it right now!
#
# But in line 17, I can use ans_1[i] because I have just made it and added it to the list. So that is why I can plot it. I use the i values in the x position, and the ans_1 values in the y position.

# %%
# f1(x)
import math
import numpy as np
import matplotlib.pyplot as plt

seed_1 = 5
iterations_1 = 10

ans_1 = []
for i in range(0, iterations_1):
  if i == 0:
    ans_1.append(math.sqrt(seed_1))
    plt.scatter(i, seed_1)

  if i >= 1:
    ans_1.append(math.sqrt(ans_1[i-1]))
    plt.scatter(i, ans_1[i])

# %%
# f2(x)
import math
import numpy as np
import matplotlib.pyplot as plt

seed_2 = 5
iterations_2 = 10

ans_2 = []
for i in range(0, iterations_2):
  if i == 0:
    ans_2.append(math.sqrt(math.sqrt(seed_2)))
    plt.scatter(i, seed_2)

  if i >= 1:
    ans_2.append(math.sqrt(math.sqrt(ans_2[i-1])))
    plt.scatter(i, ans_2[i])

# %%
# f3(x)
import math
import numpy as np
import matplotlib.pyplot as plt

seed_3 = 5
iterations_3 = 10

ans_3 = []
for i in range(0, iterations_3):
  if i == 0:
    ans_3.append(math.sqrt(math.sqrt(math.sqrt(seed_3))))
    plt.scatter(i, seed_3)

  if i >= 1:
    ans_3.append(math.sqrt(math.sqrt(math.sqrt(ans_3[i-1]))))
    plt.scatter(i, ans_3[i])
